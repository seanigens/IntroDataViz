# %% [markdown]
# <a href="https://colab.research.google.com/github/seanigens/IntroDataViz/blob/main/PolynomialRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Palmer Penguins Modeling
#
# Import the Palmer Penguins dataset and print out the first few rows.
#
# Suppose we want to predict `bill_depth_mm` using the other variables in the dataset.
#
# Which variables would we need to **dummify**?

# %%
pip install palmerpenguins

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from palmerpenguins import load_penguins

# %%
#Code Here
from palmerpenguins import load_penguins
import pandas as pd

penguins = load_penguins()

print(penguins.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %% [markdown]
# Let's use `bill_length_mm` to predict `bill_depth_mm`. Prepare your data and fit the following models on the entire dataset:
#
# * Simple linear regression (e.g. straight-line) model
# * Quadratic (degree 2 polynomial) model
# * Cubic (degree 3 polynomial) model
# * Degree 10 polynomial model
#
# Make predictions for each model and plot your fitted models on the scatterplot.

# %%
penguins1 = load_penguins().dropna()

x = penguins1[['bill_length_mm']]
y = penguins1['bill_depth_mm']

linearReg = LinearRegression()

linearReg.fit(X, y)
linearpredict = linearReg.predict(X)

quadratic = PolynomialFeatures(degree=2)
quadratic1 = quadratic.fit_transform(X)
linearReg.fit(quadratic1, y)
quadraticpredict = linearReg.predict(quadratic1)

cubic = PolynomialFeatures(degree=3)
cubic1 = cubic.fit_transform(X)
linearReg.fit(cubic1, y)
cubicpredict = linearReg.predict(cubic1)

ten = PolynomialFeatures(degree=10)
ten1 = ten.fit_transform(X)
linearReg.fit(ten1, y)
tenpredict = linearReg.predict(ten1)

plt.figure(figsize=(10, 6))
plt.scatter(x, y, color='gray', label='Original Data')
plt.plot(x, linearpredict, color='blue', label='Linear Model')
plt.plot(x, quadraticpredict, color='red', label='Quadratic Model')
plt.plot(x, cubicpredict, color='green', label='Cubic Model')
plt.plot(x, tenpredict, color='purple', label='Degree 10 Model')

plt.xlabel('Bill Length')
plt.ylabel('Bill Depth')
plt.title('Bill Depth and Bill Length')
plt.legend()
plt.show()

# %% [markdown]
# * Are any of the models above underfitting the data? If so, which ones and how can you tell?
# * Are any of thhe models above overfitting the data? If so, which ones and how can you tell?
# * Which of the above models do you think fits the data best and why?

# %% [markdown]
# The linear quadratic model seems to underfit the data.
#
# The Cubic model seems to overfit the data.
#
# The 10 degree model seems to fit the model well as the curve follows the raw data points very well.
